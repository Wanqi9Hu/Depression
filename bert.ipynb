# %%
import os
import openpyxl
import pandas as pd
import numpy as np
import joblib
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, optimizers, Sequential
from transformers import BertTokenizer, TFBertForSequenceClassification
from transformers import InputExample, InputFeatures

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from datetime import datetime
startTimeScript = datetime.now()

# %%
model = TFBertForSequenceClassification.from_pretrained("bert-base-uncased")
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
# Out:
# All model checkpoint layers were used when initializing TFBertForSequenceClassification.
#
# Some layers of TFBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model.summary()
# Out:
# Model: "tf_bert_for_sequence_classification"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bert (TFBertMainLayer)      multiple                  109482240
#
#  dropout_37 (Dropout)        multiple                  0
#
#  classifier (Dense)          multiple                  1538
#
# =================================================================
# Total params: 109,483,778
# Trainable params: 109,483,778
# Non-trainable params: 0
# _________________________________________________________________

# %%
normal_tweets_text_sample_df=pd.read_excel('normal_tweets_text_sample.xlsx')
depressive_tweets_text_sample_df=pd.read_excel('depressive_tweets_text_sample.xlsx')
also_depressive_tweets_text_sample_df=pd.read_excel('normal_tweets_text_sample_0only.xlsx')
tweets_text_sample_df=pd.concat([normal_tweets_text_sample_df,depressive_tweets_text_sample_df,also_depressive_tweets_text_sample_df])
tweets_text_sample_df=tweets_text_sample_df.iloc[:,1:6]
tweets_text_sample_df
# Out:
#               id                                               text  lable  \
# 0     1680093728              @Dreameress1 Hello!!!  Hows it going?      0
# 1     2053040367                         is on the train to london       0
# 2     2060651098  @TheLadyJane hey i wrote you a message today  ...      0
# 3     2059350074  @SuperRecords goodnight , im off to bed also  ...      0
# 4     1960820806  @SilverSteer I am always wearing turquoise jew...      0
# ...          ...                                                ...    ...
# 7995  1833084157                I can't download K-lite codec pack       1
# 7996  2214628609              @britishxo and u didnt come see me !       1
# 7997  2245101277  looking forward to a great weekend of revising...      1
# 7998  1997866869            Heidi and spencer are michigamua-esque       1
# 7999  2185800618  Only thing I miss about GSM is using my G1 and...      1
#
#                                         normalized_text
# 0                                       hello    going
# 1                                          train london
# 2         hey wrot mess today kind gam  ar ref  playin
# 3                   goodnight  im bed also  nic talk  d
# 4                          alway wear turquo jewel fav
# ...                                                 ...
# 7995                      not download klite codec pack
# 7996                                   u didnt com see
# 7997  look forward gre weekend rev gcse  monday pah ...
# 7998                      heid spent ar michigamuaesque
# 7999                          thing miss gsm us g nok e
#
# [20287 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
np.random.seed(1234)
data_train, data_test = train_test_split(tweets_text_sample_df, test_size=0.20, random_state=42)

# %%
train = pd.DataFrame(data_train, columns=["text", "lable"])
test = pd.DataFrame(data_test, columns=["text", "lable"])
train.head()
# Out:
#                                                    text  lable
# 4420                         I have a headache already       1
# 1629  @siftyboones @DenierNyc hair growth, abatement...      1
# 118                       Crying over this Denver game       1
# 1853                         Date with Derek on Sunday       0
# 4219        Ethier just hit a home run! That's my boy!       0

# %%
train=train.dropna(axis=0,subset = ["text"])
test=test.dropna(axis=0,subset = ["text"])

# %%
def convert_data_to_examples(train, test, DATA_COLUMN, LABEL_COLUMN): 
    train_InputExamples = train.apply(lambda x: InputExample(guid=None, 
                                                          text_a = x[DATA_COLUMN], 
                                                          text_b = None,
                                                          label = x[LABEL_COLUMN]), axis = 1)

    validation_InputExamples = test.apply(lambda x: InputExample(guid=None, 
                                                          text_a = x[DATA_COLUMN], 
                                                          text_b = None,
                                                          label = x[LABEL_COLUMN]), axis = 1)
  
    return train_InputExamples, validation_InputExamples

train_InputExamples, validation_InputExamples = convert_data_to_examples(train,test, "text", "lable")

# %%
def convert_examples_to_tf_dataset(examples, tokenizer, max_length=64):
    features = [] 

    for e in examples:
        input_dict = tokenizer.encode_plus(
            e.text_a,
            add_special_tokens=True,
            max_length=max_length, 
            return_token_type_ids=True,
            return_attention_mask=True,
            pad_to_max_length=True, 
            truncation=True
        )

        input_ids, token_type_ids, attention_mask = (input_dict["input_ids"],
            input_dict["token_type_ids"], input_dict['attention_mask'])

        features.append(
            InputFeatures(
                input_ids=input_ids, attention_mask=attention_mask, token_type_ids=token_type_ids, label=e.label
            )
        )

    def gen():
        for f in features:
            yield (
                {
                    "input_ids": f.input_ids,
                    "attention_mask": f.attention_mask,
                    "token_type_ids": f.token_type_ids,
                },
                f.label,
            )

    return tf.data.Dataset.from_generator(
        gen,
        ({"input_ids": tf.int32, "attention_mask": tf.int32, "token_type_ids": tf.int32}, tf.int64),
        (
            {
                "input_ids": tf.TensorShape([None]),
                "attention_mask": tf.TensorShape([None]),
                "token_type_ids": tf.TensorShape([None]),
            },
            tf.TensorShape([]),
        ),
    )

# %%
text = 'text'
lable = 'lable'

# %%
train_InputExamples, validation_InputExamples = convert_data_to_examples(train, test, text, lable)

train_data = convert_examples_to_tf_dataset(list(train_InputExamples), tokenizer)
train_data = train_data.shuffle(100).batch(32).repeat(2)

validation_data = convert_examples_to_tf_dataset(list(validation_InputExamples), tokenizer)
validation_data = validation_data.batch(32)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=3e-5, epsilon=1e-08, clipnorm=1.0), 
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              metrics=[tf.keras.metrics.SparseCategoricalAccuracy('accuracy')])
model.fit(train_data, epochs=1, validation_data=validation_data)
# Out:
# 1016/1016 [==============================] - 5744s 6s/step - loss: 0.3356 - accuracy: 0.8535 - val_loss: 0.4164 - val_accuracy: 0.8262

# %%
print ('Total time for the script:',(datetime.now() - startTimeScript))
# Out:
# Total time for the script: 1:36:16.106635

# %%
test
# Out:
#                                                    text  lable
# 2576  ha, the sun is shinin, shit! Got to do the gar...      1
# 59                 At the RBS waiting in a long queue.       1
# 8030  @benwerd And fire isn't? +1 to keeping the Hin...      0
# 5916  @stepha888 hey fellow twitterer, I've sent the...      0
# 7946                  Still in New York! Leaving today       1
# ...                                                 ...    ...
# 7686  buying my mac products... how the hell did it ...      1
# 6631                nowhere but to go straight to home       1
# 181   @TaylorLautner_  Hello ! You are rather strong...      0
# 1063  gonna have a great night out in windsor later,...      0
# 9888  @joeymcintyre Any pic of you that you put up J...      0
#
# [4057 rows x 2 columns]

# %%
pred_sentences=[]
for i in range(0,test.shape[0]):
    pred_sentences.append(test.iloc[i,0])

# %%
tf_batch = tokenizer(pred_sentences, max_length=50, padding=True, truncation=True, return_tensors='tf')
tf_outputs = model(tf_batch)
tf_predictions = tf.nn.softmax(tf_outputs[0], axis=-1)
labels = ['depressive','normal']
label = tf.argmax(tf_predictions, axis=1)
label = label.numpy()
for i in range(len(pred_sentences)):
    print(pred_sentences[i], ": \n", labels[label[i]])
# Out:
# ha, the sun is shinin, shit! Got to do the garden  L:Oswestry, England, United Kingdom: :
#  normal
# At the RBS waiting in a long queue.  :
#  normal
# @benwerd And fire isn't? +1 to keeping the Hindenburg  :
#  normal
# @stepha888 hey fellow twitterer, I've sent the email already  See you around! :
#  depressive
# Still in New York! Leaving today  :
#  normal
# There is no drug for intellectual depression...Okay, maybe there is. :
#  normal
# This is the purpose of my life.  :
#  depressive
# save the earth...don't use plastic bags  :
#  normal
# @Sophie_Lhoste ok, Im new on it but I'll write about it.... though my blog is not related 2 this.... I'll figure out  :
#  depressive
# @im_erika But of the original 5 Power Rangers, I liked the geek Billy (the blue one). Us British love to support the underdog  :
#  depressive
# It's raining!! But there are no men! I'm bummed.  :
#  normal
# depression sets in :
#  normal
# gonna find that  dino crisis walkthrough.  :
#  normal
# @creepymolester aw vee  i had no way to come get you i'm sorry.. i'll make it up to you before you go back to the moon :
#  normal
# @zininkleur Thankssss!  :
#  depressive
# @collhugstrees what's wrong?  :
#  normal
# Got done cryin with Joey. Shes like my sis! I am going to miss her like crazy! We are having one more overnighter at the hotel  :
#  normal
# @charlii1 haha. He's he'll player/ladies man tho  xoxo :
#  depressive
# Walking with bestest frienddddd  seeing the hannah montana movie later! We're cooool :
#  depressive
# Hey im back still on the myspace and bored almost done just waiting for one of the people i kare about to respond back  :
#  normal
# @FiveSecondStare LMAO!!!  i will take your advice! :
#  depressive
# Swim team monday.  :
#  depressive
# @mcflyharry HII DOUGIE, MISS YOU GUYS HERE IN BRAZIL SOOO MUCH  :
#  normal
# In bed. Still got cracking headache. 3 weeks now  :
#  normal
# Feelin' good this morning  :
#  depressive
# with alexxx  :
#  depressive
# Omg this race will never end! Poor kasey... He was doing so well  :
#  normal
# @DonoDollars lolz hell yeaaa!  :
#  depressive
# Has a cold and feels like shit  :
#  normal
# asks how can I fit a two-page table sa isang page lang? AHAHAHA. HELP ME.  http://plurk.com/p/13aqto :
#  normal
# @MaryKillelea what made you follow me, exactly? Not complaining, just curious.  :
#  depressive
# @Fantastic776 sure, I'm also frying Fishy, not not my Fishy's in the shower but real Fishy's  :
#  depressive
# @AnimeEyedGirl Shes's literally my female equal as far as depression and anxiety.She is adorable af though. :
#  normal
# Nothing like a nite in wit movies popcorn and parrot bay  :
#  depressive
# @Simone yeh it came Crashing through and now its cold  :
#  normal
# Up early preparing to do some work  Monsoon conditions at present in Sarf London. :
#  normal
# ugh major headache  and major soreness 2 more hours! :
#  normal
# @mileycyrus  i voted for you already (: good luck!  :
#  depressive
# @ColtonThomas01 I have both! Generalized anxiety disorder and v mild depression :
#  normal
# @Shontelle_Layne LOL, I'm listening to that song right now! Jai Ho back at you!  :
#  depressive
# @KRAPPS LOL I wasn't looking at the beer opener, it's a piece of krapp  :
#  depressive
# @KatGirl44 dunno...twitter is your bitch i suppose. btw i just got a comment notification from happy sperm  :
#  depressive
#  baby you like my favorite dessert I just can not get enough of you love you I'm yours 4Eva :
#  depressive
# @dolcedebbie Welcome to the Amalfi Coast! Hope you have an absolutely lovely stay!  :
#  depressive
# last night was absolutely ridiculous! cant wait to do it again tonight  :
#  depressive
# @bluebuttons Wow that is definitely going to be Matt and I. Can't wait to see you Thursday  :
#  depressive
# Sony and Nintendo today  Wheeee :
#  normal
# another Monday and it so gray!   I guess yesterday was our summer. :
#  normal
# @shivgreen we'll watch them all in the 2 weeks, i have the complete season 5 and 6 on my computer  :
#  depressive
# well bens hangin out with dad so i have to go to bed  :
#  normal
# @magshad Heard the football news... my condolences  :
#  depressive
# friggin slept in   no early morning digimon for me.  and i'm off! :
#  normal
# Irish Times - Eircom (ESOP) supporting STT bid for Eircom, quick buy Eircom shares, you could make a killing or more likely get burnt  :
#  normal
# @shawnieora wow - did the cop ask for an autograph?  :
#  depressive
# hanging out in Beth's apartment. Then seeing The Proposal later. REALLY missing my baby  LOVE him so much. &lt;3 :
#  normal
# @GuyHagi Pukalani light winds and voggy. Heard the landfill was shut down due to bio-diesel tanker fire. Otherwise, doing house chores.  :
#  normal
# @JulieAnnStorr &quot;Change is made by asking forgiveness later.&quot; never been much of a permission asker myself  :
#  depressive
# @EvilTart awwww!! i want a cat  :
#  normal
# Thanks @mylescollins our propoversary is happy.  :
#  depressive
# @lil_bit_tina OH SHUT UP U KNOW HOW I  GET IN THE MIDDLE OF THE NIGHT WHEN I GOTTA SLEEP ALONE  :
#  normal
# More like Depression*  https://twitter.com/avengers/status/988576000349896704 … :
#  normal
# @mattcutts lol I wish that like every day. You're lucky @vanessafox doesn't come after you for that slip though..  :
#  depressive
# Bed, school in the morning. Gym final tomorrow, jogging for 12 minutes ?! Sweet. Oh let's not forget the swimming and written part!  :
#  depressive
# Cures depression :)  pic.twitter.com/ZO9c1hgS73 :
#  normal
# @AntoViral Thanks & great you promote ppl with depression to be active. Robust evidence exercise helps people with depression  https://www.sciencedirect.com/science/article/pii/S0022395616300383?_rdoc=1&_fmt=high&_origin=gateway&_docanchor=&md5=b8429449ccfc9c30159a5f9aeaa92ffb … with comparable effects to iCBT https://www.cambridge.org/core/journals/the-british-journal-of-psychiatry/article/physical-exercise-and-internetbased-cognitivebehavioural-therapy-in-the-treatment-of-depression-randomised-controlled-trial/66708A9B8C66ACF80FCA040784E5E9CD … :
#  normal
# Going to sleep now i gotta get up early tomorrow to go workout  Hope i dont get to soar I have a party to go to tomorrow  :
#  normal
# @MrBlippy it's dying  :
#  normal
# @alejandralei thats what everyone is telling me. i dont care.  :
#  normal
# I'm not use to the fact that I'm finally 16. OH MY GOSH, I'm 16!  :
#  normal
# Backpain still hurting me  :
#  normal
# @princesssuperc we're at the concert now; and you just said tweet you so here you go!  xoxo :
#  depressive
# i didn't go to school, i was with stomach ache   and now i've to study more!  bye bye twitter, later i come back!  :
#  normal
# @triskasue If we get any rain, I'll send it to you Pattie.  We need it bad too!  :
#  depressive
# @applegirl there to greet you when you come home too or no?!  :
#  depressive
# The Reds didn't win and Votto came out of the game again.   Feel better Joey. We'll get 'em next time. Go Reds!!! :
#  normal
# Huge turn out at ATC track meet tonight - guess folks are starting National Running Day early!  http://tinyurl.com/AW6Tvqrp :
#  depressive
# @qu33n1315 yeah thanks! ill look at it when im done on this.  :
#  depressive
# colleen's house with katie, then basketball in walpole and driver's ed  :
#  depressive
# @nattycakes ok..stupid idea to try to hug him while he's in transport somewhere. I say we booze him up and then kidnap him  :
#  depressive
# If you ever want to look as awesome as this...You should treat yourself to one of our tote bags :]Just like @NicoleDivide did!<3We support those with depression by donating 50% of our profits to @MindCharityPlease re-tweet! http://InMusicWeTrust.co.uk  pic.twitter.com/X7qxH7chID :
#  normal
# Point failures outside Liverpool Street station are starting to be a constant fixture in my morning commute  :
#  normal
# So, Im every greatful to @gayleforman for mentioning me on her blog in her BEA post! I &lt;3 Gayle!  Check it out here--&gt; http://bit.ly/658kk :
#  depressive
# @lilyroseallen Got tickets for your gig in Glasgow, gutted we have to wait til November though  :
#  normal
# Please send me some karma  (via #zenjar ) :
#  depressive
# urgh i'm awake soo early and i feel really sick +o( .. gutted i missed prias party yesterday!!  sucks so badly(n) :
#  normal
# @estellegoh haha.. i think *most* girls cry easily.. lol.. we're very sensitive!  :
#  depressive
# All good. Marvin Gaye makes it all fine  :
#  depressive
# i'm not sure i understand everyone here, but cheers to you all anyway.  :
#  depressive
# I'm now watching 16 and Pregnant - so, so sad!  :
#  normal
# @ChrisHangsleben what?!?!  boo why..... :
#  normal
# just got poptarts from Publix  My dad is jamming on my guitar in the other room...what a weird night.. :] :
#  normal
# Been up all night now @ work wishing I didn't go out last night...  25 more mins :
#  normal
# bank holiday today...apparently  :
#  depressive
#  I get to do a review for Katie and Nina and for Colette when it gets here...... LIFE IS GOOD!!!!   :
#  depressive
# Watching Edward sissorhands! Cause there is NOTHING else on the tele box  x :
#  depressive
# I liked a @YouTube video  http://youtu.be/kSvJDeXnwXc?a  Mensutra on Kapil Sharma's Depression and Phone Call Controversy! :
#  normal
# So, two things, why can't people just grow up when they need to? And.. I decided, i do want kids! At least one!  :
#  depressive
# @Dravie Im so not listening. cant believe I'll be missing spn tomorrow  it'll be worth it to not have to work on my bday though :
#  normal
# @stephenfry owwww i don't envy u at all  :
#  depressive
# @keisha_buchanan he looked amazing wearing my pint  :
#  depressive
# @filcro Oh, right; makes sense, I guess.  :
#  depressive
# *mwah* my lovely ladies!   i am out!  dont let those silly boys get u riled up...it's just like theyR pulling ur hair on the playground  :
#  depressive
# talking to tim from Australia, and he wont speak with an accent  :
#  normal
# Still no iPhone OS3?  America must be awake by now!? :
#  normal
# Soaking wet from rain  :
#  normal
# So I've been gone for about a week and now I can't keep up with my LJ and twitter  :
#  normal
# yeah here it comeshere comes the depressionrrrrrrrrrrrRRRRRRRRRRRRREV IT UP :
#  normal
# good morning  :
#  depressive
# @steiger congrats! Get ready for a million more subscribers  :
#  depressive
# The thing about depression is that you never see a low coming. You wake up and are bubbling over with contentment. And then it just ambushes you and before you know it, you're in the sunken place. :
#  normal
# rly should take dog for a walk and yes. Gonna go get a pizza too  :
#  depressive
# Arrived at Lazerfest. Saliva's playing. Nice!  :
#  depressive
# Ha ha! I got up at 5:30 this morning.  :
#  depressive
# Yaaay, my Superpet (Badger, The Racoon) has progressed to level 8  &lt;3 :
#  depressive
# Argh. My feet &amp; my back hurts!  :
#  normal
# @AreeLulibub Hey Aree! Have fun at the lake.  And woot, go Relay!  :
#  depressive
# Is out with smartiepants and Dano  http://myloc.me/2YJM :
#  depressive
# @4everBrandy That's too cute. Sounds like how I would talk to my mama  She will get a hang of it! :
#  depressive
# @sbrondum my eReader pro doesn't work right now. I can't switch between books.  î? :
#  normal
# misspelled those wrong  :
#  normal
# Always thanks to my brother for waking me up early. Now about to get some fuhh and then go paint!  :
#  depressive
# mr. willard's poool partyy.  :
#  depressive
# @the_grey_goose aint got no tv @ my sis place! n too tired 2 go out 2 watch it! but goooo lakers!  :
#  normal
# hey , @LITTLEWINDMILL !! cute picture, i like the colors. =p~ are you back ?  :
#  depressive
# @katdrabeck i concur.  :
#  depressive
# @Luvmentalhealth @AdamHoward2000 Seriously..ppl are so judgemental. What makes him/her an expert on your depression or illness? :
#  normal
# A million memes a day,keep depression away. :
#  normal
# Just got my blink tix in the mail  :
#  normal
# honestly hit depression this week, someone cuddle me better :
#  normal
# wants To do something in Barry  http://plurk.com/p/rq1z0 :
#  normal
# Good morning Twitter world  :
#  depressive
# @RaissaLMF aiden davis rocks --flawless are awesome too  :
#  depressive
# Realized that jakes been gone for a year now.  :
#  normal
# @crazyBobcat Very worth a try. I plan to be napping shortly.   :
#  depressive
# Hols = J's during the day  Ice Cream again very very nice indeed :
#  depressive
# @agarcher I can't access any of the links on @strife25's server.  Whaaa!  Feel like I'm really missing out  :
#  normal
# Isn't going to be able to do the voice recital...   :
#  normal
# is starting to hate the summer all ready. too damn hot  :
#  normal
# New, #free #WP theme coming to Blogsessive.com next Monday! Stay tuned, you'll love it! PS: Not a blog-style theme  #WordPress :
#  depressive
# thanks  http://newsweek.com  for helping bring to light a HUGE problem. Childhood is for fun and laughter NOT trauma, abuse, and anxiety. Join us in helping them regain childhood at  http://chaoticspyder.com #ptsd #mentalhealth #kids #parents #teens #depression #trauma #abuse https://twitter.com/ISSTD/status/989158405532258304 … :
#  normal
# byeeeeee tweeps  :
#  depressive
# @dougiemcfly Theres a really sad film out .. dont think it wil be your kind of thing tho?? My sisters keeper .. its sad ..   :
#  normal
# http://twitpic.com/6rf2m - I wanna go to the SEA  í´ì´ëâ¬ :
#  normal
# @thelostofficial nice - I like! thanks!  :
#  depressive
# next week is the last week of school! yay! and then on the 8th im off to the bahamas! ya! paradise here i come... well in 9 days that is!  :
#  normal
# @LoveMyNuts Very doubtful  :
#  normal
# @laceystone Ugh, of all days! No, I will be in Rehoboth that weekend  :
#  normal
# @Arcania, in about two hours I'm setting out on a 600-mile drive home. Mostly I'm hoping it goes quickly.  :
#  depressive
# @hobomagnet yes...in fact it will. Signed...ray of sunshine  :
#  depressive
# @pepperespinoza *pets* Poor Pepper  It's the curse of Monday. :
#  normal
# Give to charities? http://twollars.com/charities/ Send them Twollars or BUY their Twollars  rt @SofieReed #ecomonday :
#  depressive
# @garrbage Insecurity, depression and psychological projection :
#  normal
# i am so not Happy!!! i left my phone at home today  Grrr :
#  normal
# ugggggh i wish josh would go to the drive in! that would be awesome for date night! but nooooooo, he's a party pooper.  :
#  normal
# Hit up our MySpace :: http://www.myspace.com/outtogether  :
#  depressive
# @SteffiF I agree, I am sitting on the sofa with a blanket! Def. cold  :
#  normal
# Change. Unexpected, unwanted and unavoidable change first thing in the morning really puts me in a foul mood.  :
#  normal
# @lizmoney Apple's in-ears are slightly comfy for me -- slightly loose in one ear, but that's me  There are multiple ear tips, of course. :
#  depressive
# All matter is energy, all energy is information. Information is thought, thought is consciousness. Consciousness is All That Is  :
#  normal
# @FitnessforGolf I understand now  :
#  normal
# @JulieeM awh you poor thing  i'm in pain too with this sunburn :
#  normal
# once you go mac .. you never go back !  (via @PalStall) :
#  normal
# 5:30am and my new album 'Dyamond' is COMPLETE! Now we narrow down 32 tracks to 15 that will make the album  :
#  depressive
#  @billbeckett's signature has 100% rubbed off my mondayeyes bracelet. At least I have plenty of autographs from him, but still. Sad day. :
#  normal
# @kainui_carroll legal cultural stuff!  srsly, the people of pacific club have a kava night every year ;D :
#  depressive
# @tomasbreffitt @gtrichey and it's getting a bit annoying, with quite a few days to go in the promo. People tagging randomly now.  :
#  normal
# Beach is beautiful! Down here already! Ready for a mimosa.  :
#  depressive
# @sweetney   so sorry to hear that.  i will be thinking of you. :
#  depressive
# And I guess, I just have to make sacrifices if I want to achieve my dreams. My family is very supportive at least (it's just, I can't stand living with them, as I need my own space and freedom; I feel trapped here). I just hope I can work through the stress and depression. :
#  normal
# @clarkalastair @warped0ne sorry, no Brooklyn for me today, was not watching my DMs (too much DM spam from idiots)  :
#  normal
# @PerezHilton sadly thats how the show goes, they have to sing/do what they did in the semi-finals  :
#  normal
# Depression. I care barely got out of bed. :
#  normal
# BBC NEWS | Technology | BT to roll-out faster broadband http://bit.ly/7erIh Bet I am one of the last to get it  :
#  normal
# I am NOT going to allow my depression to take over my life again. my mental health is going downhill again and i'm not going to let it. :
#  normal
# More troubles with Skype  :
#  normal
# @daijamae Hiya Hun!! Been great ta as been off on leave all week - not looking forward to going back to work tomorrow  How's you? :
#  depressive
# Ppl you must eat at Sumo Salad in the city! My bro jus bought the business and its sick! Oh they need staff 2 k! Get to it ey  love x :
#  normal
# Just realized I can't play gemcraft on this loaner comp unless I want to start all over.  Unless I can sort out where the saved files  ... :
#  normal
# @bidorbuy - Yes everyone gets a free bidorbuy community toolbar  Share this with all bargain hunters! :
#  depressive
# @jackalltimelow wow, just noticed you changed your background. what is it? junkfood??  :
#  depressive
# Heavy use of Facebook is linked to stomach aches, sleeping problems, anxiety, depression and narcissism in teens. :
#  normal
# @jesssicababesss hhaaa  jelous! and alright if they say out be like yur... :
#  depressive
# hates being sick.  ... but loves stereos, they made my day brighter! &lt;3 :
#  depressive
# I wish things didn't bother me so much, the smallest thing & I feel my world come crashing down. Why is depression/anxiety so cruel? :
#  normal
# Cleaning the fish tanks - one of my cichlids died last night.  All other fishies seem fine! :
#  normal
# ze bastards removed the soundtrack of my skydive video  :
#  normal
# RAIN RAIN RAIN  I need more followers to make me feel better. This weather is so depressing... www.talkofdc.com :
#  normal
# @badboymoe im in florida homie  dont got the funds to get up there right now :
#  normal
# @jg_rat hello  are you back from your trip? :
#  depressive
# @TomVMorris The importance of playing and of releasing your inner child - keep on playing - bubble on!  :
#  depressive
# @vampiravalo for my birthday which is in June...Either Razorblade Romance or Deep Shadows and Brilliant Highlights would be cool.  :
#  depressive
# curled up on my mum's couch, with the heating on, a hoodie, a blankie and i'm still FREEZING... i'm coming down with something, aren't i?  :
#  normal
# Ouch! I just poked myself in the eye .... with a book  :
#  normal
# @karinb_za we are down to our last R100 - payday is fri. Pls pray no surprises this week *sigh*  I hate this. :
#  normal
# oh why oh why did i ever choose, video documentary for my thesis. i should have chosen to do an interactive bla bla thing.  :
#  normal
# @WorldofOutlaws I am gonna need depression meds soon, these rainouts are spinning my equilibrium out <Emoji: Pouting face> Mother Nature is being a mean B-T-H <Emoji: Face with symbols over mouth> :
#  normal
# quem vai pro show em recife? eu!  AUIHSDUIASHDAIUSDHIU #fletcherday :
#  depressive
# @Malarkey After reading the pro scaffolding comment I just snotted over my keyboard from laugh combustion  :
#  normal
# @thedenonline  I hope everything went well  last night &amp; a good time was had by all  :
#  depressive
# @jonconley omfg nerd! but at least you get it when i say that. no one else does  :
#  normal
# I wanna go to America! it's too expensive though  gosh. so unfair! :
#  normal
# My sinuses are going to 'splode.  No bueno. Time for more Alavert and hopefully sleep. :
#  normal
# @vogleratmizzou yay about breaking 200!  :
#  depressive
# @JKsGirlx2  don't even worry about it. I'm just teasing. I did get desperate though and went back and re-read BT.  :
#  depressive
# Someone is still taking a nap &amp; not helping--&amp; it ain't me! I'm in the home office &amp; feel trapped. So much to do; so little time. Yikes!  :
#  normal
# Business taxes all done and I don't owe anything.  Which, I suppose, is both good and bad.   :
#  depressive
# Oh It's Over  :
#  normal
# @theintercept Is there anything that isn't just outright fraud in this country anymore? The generation that survived the depression and defeated fascism are so proud I'm sure... :
#  normal
# @PixiePolaroid Technically camera aren't allowed in the concerts  But still, i'd love to have some photos from the NKOTB cruise  :
#  depressive
# Wow. that blog took me 2 hours. i bet i've missed loads as well. anyhow, best day of 09 has been blogged about  :
#  depressive
# Hanging with my bros and their friends.  Good guys. Holiday World Tomorrow! :
#  depressive
# Depression real deal hits yo ass outta nowhere. It can sometimes come mid laugh when you wit yo friends. Or when you In the middle of writing notes in class. That shit sucks son. :
#  normal
# hi @bLuE_hEfNeR ! I would suggest music of my electro project *** http://bit.ly/12KoF0 *** fresh, kickin', different! free dl &amp; have fun  :
#  depressive
# I'm going off twitter for a bit. Feeling depressed. Since the passing of my auntie. Im too upset for this. Especially the stress of being ignored sometimes. Which adds to the depression. :
#  normal
# @shaneb Tried as hard as I could to stay away from BSG spoilers when I wasn't up to date, and yet it still happened. Still, I apologize.  :
#  normal
# @AsteriaArgent Its good to hear ^^. Sometimes i kinda worried since seems half of my mutual have stress, depression and anxiety. Please don't hesitate again to shitpost if you feel bad again, i believe there ppl care for you :) :
#  normal
# back from a sunny walk, weather is so nice,which is unusual, the murphys are pikin me up which shud be goaad. want to go out in the sunn  :
#  normal
# How to fight depression and loneliness? Crime docs. Thanks, Golden State scum. Now I'm all watching horrific things because...I never know why, but murder shows alleviate anxiety and depression. Maybe because it makes me feel like a detective. Or maybe I just miss Robert Stack :
#  normal
# Celebrating my aunt's birthday... without my honey..  :
#  normal
# @JonathanRKnight Hehe That would be pretty cool! Have a safe flight!  :
#  depressive
# had an amazing night with two great girls!!!   &lt;3 you both!! :
#  depressive
# @LaurieCromie I think I didn't even come for the Jack. Sawyer, though?  :
#  normal
# @Kunene_Lonwabo @kanyewest What's happening with Kanye West? Is he suffering from depression? :
#  normal
# Found a tee  now looking for glow in the dark stars hmmm tricky :
#  depressive
# Depression kills yo :
#  normal
# @jun6lee I'm Woohoooing with you  :
#  depressive
# @sodaly Haha, that's perfect. &quot;Twitter, circa 1897&quot;  :
#  depressive
# Shootin pool at Stardust with my favorite boys!  :
#  depressive
# @pagankinktress Anything you might want to make glisten and slick and tasty   Imagination is a wonderful thing :
#  depressive
# haha wow i believe i just got dumped.boys suck  :
#  normal
# it's a good time to.. smile!  :
#  depressive
# Guess where I'm at? Ill give 1 1/2 guesses  http://short.to/9bkh :
#  depressive
# had a great night last night, and happy mothers day to every mother in the world  :
#  depressive
# @DenalisAngel thats bad  .... WHAT R U DOING ON TWITTER????? GO STUDY !!!! :
#  normal
# I'm so mad that I can't finish watching my show! It was supposed to take 40 minutes and it's taking more than an hour.  :
#  normal
# didn't catch a single fish. my 2 year old brother caught the biggest of the 3 fish we caught. i'm the only one who didn't catch anything.  :
#  normal
# - on da phone with alicia hauser, singing together!  :
#  depressive
# can't seem to ever get enough sleep  :
#  normal
# 'Depression symptoms, having to travel outside the respondents' community to give birth, and being born in an East Asian country were associated with lower levels of satisfaction.' :
#  normal
# @selenagomez DAVID CALL SELENA!!!!!!!!!! I'LL GIVE YOU A COOKIEEE!! forward that to him  :
#  depressive
# @lizstrauss  your welcome. :
#  depressive
# @wolwol Duh duh, startrek only in jakarta for now  &gt;&gt; means, you must watch in Jakarta, and have a meet and greet with WFC members ;) :
#  depressive
# This time next Saturday, Ill be on a road/day trip w|my girls! Can't wait  :
#  depressive
# @mmitchelldaviss your photography is killer&amp; so is your style, keep being awesome  woot! :
#  depressive
# @NotARichGirl The shampoo I used was the soothing lavender + peppermint.    I no like. :
#  normal
# Sasquatch are REAL I just saw one at the drive thru, I got their autograph  :
#  depressive
# I really wish I could get the Pangea Patrol set on #packrat on MOO stickers - I seriously miss the 128px artwork  @iconmaster @SanLei ?? :
#  normal
# OK not that I am loved  but this will be the last time for a while I can log in unless I get internet signal on my Phone! So tata!  :
#  normal
# @GEEBIS haha thanks, how has your day been so far????  :
#  depressive
# @Starr_Baby Awwwww I hope your son feels better  :
#  normal
# I am struggling with depression right now—I have panic attacks every time I sit down at my desk and I feel so adrift—and I frequently regret not becoming an actor. That regret has only intensified ever since a girl from my college's drama department got engaged to Prince Harry :
#  normal
# finally posted Holy Week and Easter music on the blog. Next up: practice, spending time w/friend from Sacramento ... then Drabble Night!  :
#  depressive
# @phpinto  :
#  depressive
# I just joined twitter!  :
#  depressive
# Marlins/Mets game. Backstop says &quot;mets.com&quot;  &amp; &quot;losmets.com&quot; on next panel. Hubs just asked why they show something urging Mets to lose.  :
#  depressive
# @TriggerStreet I read that cinemas may be taxed for the films they show, may shut down some smaller non multiplex theatres.  :
#  normal
# Is adding finishing touches to her website...which will be launched on Friday  :
#  depressive
# @Patti0713 Weird and bloody HOT!! He was HOT HOT HOT!!! Hugh Jackman-like hot! hÃ©hÃ©hÃ©  :
#  depressive
# I wish I was at Ocean Breeze  But atleast the O's took 2 of 3 from the Mets! Ha! Take that Bobby!!!! ~Chaps :
#  normal
# Truckers of the depression army.  https://twitter.com/i/moments/989121234813292545 … :
#  normal
# @MistaSajoo every video yousned me somehow gives me depression :
#  normal
# somthing you dont care  :
#  normal
# Crawfish Boil today! Saaaad it's raining  :
#  normal
# I wanna be wif my boyfrannnnn  :
#  normal
# @curlsdiva There's so much music we haven't heard but that's good. All the more to discover  :
#  depressive
# I'm afraid of episode 10  :
#  normal
# If I drop off - sorry - I'm so close to drooling &amp; snoring LOL - goodnight in advance - will try to make it to 9 tho  :
#  normal
# @Patrikianpolk everytime LOGO is twit I ask/beg 4 NA to be on! But I will ask/beg U! please!!    :
#  depressive
# @PembsDave Good thanks watching GP. F1 tyre flavour #crapcrispflavours. How are you today? U seem on form  :
#  depressive
# I cannot actually believe that we have to do another #SharePoint rebuild. I've lost count!!! Never mind time... Ugh. Cup of tea time  :
#  normal
# 70 IQ should be solved in 30 minutes ... I'm sorry my dear brain .. I know it was hard .. but it was Ok also  :
#  normal
# @darwinmago is down with a fever  saddest weekend ever. :
#  normal
# i wanna twitter so badly, sumbody twitter me  :
#  normal
# @CocaBeenSlinky  Aldo not a risk methinks, lot of luv 4 and from him at Prenton Pk still, he fell out with boss last time an she gone  :
#  normal
# is sad she couldn't go out with her girls tonight  It's been too long.... :
#  normal
# Loving my new iPod touch!!!! &lt;3   :
#  depressive
# @bradeinarsen Thanks, yeah, do indeed have access. Have to remember to open in IE for the fun stuff  Curious about non-email apps too tho. :
#  depressive
# is in her favour-ite state  :
#  depressive
# FINALLY watched the season finale of grey's anatomy! but man what will next season bring??  :
#  depressive
# wat a rainy day..... im so bored  :
#  normal
# @Latinvixen Interesting new style of coloring  I think it came out very nicely :
#  depressive
# I don't know how to make leis, so I need to go buy some  :
#  normal
# I will love to death the lovely one that will give me the CD 'A Little Faster' on my birthday.  :
#  depressive
# one week of summer left.  before i start summer school.  yay.  :
#  depressive
# Gah!! Holiday is ending  :
#  normal
# Getting rdy to work my 12 hour shift today!  oh how I dread ittt... Js gotta think positive! :
#  normal
# is depression considered a terminal illness if someone commits suicide :
#  normal
# Hoping @allyp and @jeff318 have a safe flight and get back on time!  :
#  depressive
# Time to retire for the evening..... Tomorrow will be another beautiful day  :
#  depressive
# Today is the day!! I'm graduating at 12:00  :
#  depressive
# So u spend ur whole life thinking & dealing with things the way u deem right then at 33 realise no,that's not how things r done.That's not how you should be living your life. t's so hard to try and snap out of that mindframe. #depression #anxiety #coping #mentalhealthmatters :
#  normal
# I guess the relaxing dinner and a movie is out for tonight...I was looking forward to that after my day at work  :
#  depressive
# What stereotype do you think you completely live up to? — Um. Probably that millennials are lazy, entitled, etc. I totally am. Oh, and the whole depression...  https://curiouscat.me/hopkinsian24/post/430611915?1524699653 … :
#  normal
# @teenotify thanks for the Threadless nomination  :
#  depressive
# Listening to Geh - Tokio Hotel  love that music &lt;3 :
#  depressive
# Funny how running fixes everything  :
#  depressive
# Jialat! Need something to get over my permenant grouchiness  :
#  normal
# @Fitted_Nerd no hes not. well i hope not. then theres another sexy ass black man gone to waste  :
#  normal
# Just found two huge mosquito bites on my back.  theyre like pennies. :
#  normal
# Just walked past 1 of the male models at the lifts and loved evey minute of it. . . how sad  :
#  normal
# Go Katelyn! Go Hannah! Awesome job girls!!  :
#  depressive
# What does a man have to do to get a freaking graduate position?  :
#  depressive
# digg: Pogo Stick Fail [Gif]: He tried to do a backflip.  http://tinyurl.com/m7762g :
#  normal
# In my case... With really bad writing and a bad sense of humor  :
#  normal
# just woke up...and wants more sleep  :
#  normal
# @hobcleveland i wish i was  :
#  normal
# @julieshelley  :
#  depressive
# @ariyaly hope u feel better too ! suUuUucks.  :
#  normal
# i think its about time i got off my lazy ass and went for a shower, soo bye everybody  :
#  normal
# @CXI i have that happen to me occasionally too. freaks me out too far!  :
#  normal
# Mourning the loss of David Carradine!  the clouds right up there say they agree with me!  :
#  normal
# @kitlammers We're  both dorks  :
#  depressive
#  needed new earphones, got new earphones. :
#  normal
# @mollyblock   Ha!  Awesome   You are always the best new people finder I know. :
#  depressive
# of course the mindset of a knetz who can't grasp the concept of depression/ mental health and thinks going to church is the answer to everything.  https://twitter.com/seulgiseulgay/status/989033564170842112 … :
#  normal
# @appleconvert yea i no, your lucky! It's a 2.1ghz White Macbook latest model, should be coming back this week *fingers crossed*  :
#  depressive
# having momma and daughter quality time .. the others aren't home ..  :
#  normal
# Ugh, why does all the cool stuff happen when I'm not free?   http://tr.im/myun :
#  normal
# @yoko71 @ItsNeet Ladies, thx 4 assisting me with the iTunes thingy. Hwvr, it looks like they've taken down the tracks except for d Top 4  :
#  normal
# @kcarruthers its MY first chocolate since #livelocal - how long did YOU last?  :
#  depressive
# KUhawk5  Ooops.. I had a bug   But I fixed it..    Try that tiny URL again.. :
#  depressive
# @aussiecynic Blow me away it IS raining harder here. Yay you, well done  :
#  depressive
# @AaL17 Aw, bummer! But at least you can re-watch it  My net disconnected 4 times  I got angry and swore  :
#  normal
# Enjoyed the awards for the most part.it was nice to c so many peeps tonight. In EDH till Sunday, so hit me up  PS Can't wait 4 New Moon! :
#  depressive
# ahhh big spoon with austin was amazing  :
#  depressive
# @neosolrkstr I am about through Sis.  I am beat.   :
#  normal
# i want to be able to take a break from the internet to help my depression, but i can't. i'm already addicted to it like a drug, and a lot of my school stuff depends on it. i can't run away. :
#  normal
# Junk food a factor when it comes to depression, says Dubai doctor -  http://ArabianBusiness.com  http://dlvr.it/QQjRdF  :
#  normal
# @fakealiens No, I like your hair. You're so sexy. and the mohawks would be so cute  xoxoxo ilu :
#  depressive
# Feeling very crap today, so wish I didn't...have singing tonight.  :
#  normal
# No good movie releases this weekend  :
#  normal
# Back from Germany  :
#  depressive
# @uNdlunkulu_Xoli Listen to your heart , surely it telling you to keep the baby cause if you abort the child and 2 years years later he decides to end your relationship you will regret it for the rest of your life and depression will be all over you<Emoji: Face with cold sweat><Emoji: Face with cold sweat><Emoji: Face with cold sweat> :
#  normal
# Lets all party at the corner  :
#  depressive
# @little_eva sounds yummy! have some for me  :
#  depressive
# waiting 4 my coffee 2 brew what would i do w/o it?  :
#  normal
# last concert of the season tomorrow  :
#  normal
# strep throat  :
#  normal
# @KimKardashian Really disappointed that you cancelled your appearance @ club Karma in NJ! Have been looking forward to it for weeks  :
#  normal
# mtv movie awards tonightt!  :
#  depressive
# Going for a cycle a day helps keep depression at bay #mentalhealth #activelincs #bikeability https://twitter.com/WeAreCyclingUK/status/989051846772822017 … :
#  normal
# @mikexcore Happy Birthday   :
#  depressive
# Say my name, it's sound so sweet  :
#  depressive
# BTS saved me from committing suicide.I hv never told anyone abt dis but today I want to share. I knw giving up is not the only choice but during severe depression u can't think of something else. I m learning from them.I m working hard nd I m better now. Thanks to BTS. <Emoji: Heavy red heart> :
#  normal
# . @drtiki And a big Thank You for the gift you sent over.... Thanks!  #SLL #strangelovelive :
#  depressive
# My insect bites are seriously annoying! VERY intchy and swollen  All together there is about 14!!! Oh man.. trying to stop scratching! :'( :
#  normal
# last day in marrakech  oh well hopefully the plane journey home might give my sunburn a chance to die down... :
#  normal
# @step_up_steph its fine. I don't know if ill get mine. They leave in 30 minutes &amp; it usually takes 45 minutes from where I'm standing at  :
#  normal
# @mcflyharry Harry Potter.  :
#  depressive
# listening to. so It's pretty weird. headed to sleep for the night  soo goooodnight and gooodbye (@JonasBrothers:: that song has been in my :
#  depressive
# It took me two hours to go grocery shopping and I have no energy left to drive home, so I live at Publix now, I guess. #depression :
#  normal
# @absoluttitanium lucky bastard...brandy went to pick me up something... and she said there was nothing fr girls...  u on ur way home now? :
#  normal
# Missy higgins kate voegele grace potter and the nocturnals  :
#  depressive
# had another lonely train ride. even sadder when the train stopped at his stop and he wasnt there to say bye to him at that stop.  :
#  normal
# I want a white iPhone 3gs  :
#  normal
# Eish. Prob won't be winning that jersey from @BobSkinstad based on the current score. #lions#rugby  :
#  normal
# @zephyr0811 hope ur migrane is better now  :
#  normal
# 65 emails, 24 direct messages. Thanks Twitter :') preparing to follow some more today. Hope everyone is having a good day  :
#  depressive
# My eye is killing me i need to go to the eye doctor  i cant wait for my vacation to start :
#  normal
# @Nem276 dvaes channel? cos if you're on about daves channel then that happens to him all the time  but i'm not dave, so, you know, lalala :
#  depressive
# @Esbatty I actually only have Sudafed for congestion and some brand-x CVS Pharmacy shit for allergies. i wanna be claritin-clear  :
#  normal
# Is at the Y... Last day  :
#  normal
# had a great day today.. excited for tomorrow as well  :
#  depressive
# out of the shower now, and am the coldest im going to be all day  its not fair! :
#  normal
# Catherine Neal Sandifer has twitter! Follow @CatherineNealS  she's so cool :
#  depressive
# @Lauren2206 Well hows the head lol?  Can't say im the most fantastic condition today.  Really wish i was out in the sun  :
#  normal
# @Jerseygal71 damn! sorry to hear that but glad you came here. Would hate to lose touch with you  :
#  normal
# @billsrevenue Up to $200 CPA and 40% rev share plus tons of free tools (design marketing, seo). Let me know if you'd like more info!  :
#  depressive
# @cephaler highland park diner! Duh  :
#  depressive
# A little bit of Bom Chicka Wah Wah + Boom Boom Pow = Dolce ON TOP OF THE WOLRD!!!! HAPPY FRIDAY EVERYONE  :
#  depressive
# Damnit, all I want right now is a controller to plug into my PC to play some SNES roms. That's it. I can't find my Dualshock USB adapter.  :
#  normal
# @Jillfoster &quot;the&quot;? Wow.  I'm nearly with you. :
#  depressive
# Been going round and round in Tigaraksa, can't seem to find the factory  :
#  normal
# I hate being tired and antisocial when my friends are at my house  :
#  normal
# No one understands how much he has helped me with. I have seriously never been in such a better place, I haven't had to see mental health in a long time because he relieves all my stress and depression. Sometimes you just need someone to help make things better... so thankful<Emoji: Heavy red heart>  pic.twitter.com/YsJq5CXjXs :
#  normal
# @Silver_Craig not heard many Aussies then?  :
#  depressive
# i think my LV&amp;TT is missing a picture in the booklet  :
#  normal
# Oatmeal raisin cookies with rootbeer kisses mmmm  :
#  depressive
# i wanna make fun of locals for always talking about post concert depression..... but that shit............. is actually so real :
#  normal
# Depression is a bitch :
#  normal
# is awake  :
#  depressive
# @segdeha If you figure it out, be sure to let us know  I've been wondering that for a while. :
#  depressive
# @BlairVander I'm not sure where to recycle. My housekeeper ssort it out for me. Or taht's what she says... who knows?!  :
#  normal
# Got Twhirl  and its really convient :
#  normal
# @krazyyleggs haha. how amazing would that be. let's do it. scratch that. lets just move to vegas.  :
#  depressive
# Waiting master chef Australia  :
#  depressive
# @perrymanmd on to the next project now, right?  :
#  depressive
# @LloydDavis I was just looking at that!  Terrible...far too familiar  :
#  normal
# @FredaMooncotch what are the requisites for being an alpha woman? I want to be one!  :
#  depressive
# @LisaMei62 That 98% tax for working class is what was talked about to cover Bernie's big ideas during the election. Think that's not possible - FDR did it during the depression - If you want to see what would be result of this plan - search Venezuela economic crisis :
#  normal
# Oww. My eye stings.  :
#  normal
# high school is over and i still have so much work  :
#  normal
# @Yeti_Antics Yes, indeed. It really ruined my day, but it is now fixed. However, it's taking the entire night to get it decently cool.  :
#  depressive
# - noooo!! the iPod has reset itself and deleted 30GB of music  and still waiting for the Florence &amp; the Machine album to be released :
#  normal
# @pocahontis Happy birthday! Hope you have an excellent day with lots of cake. In moderation, of course.  :
#  depressive
# owing to 'progress' on the west coast main line, tis anybody's guess when I'll get to rural station/work  :
#  normal
# i think i got my dad a bad fathers day gift   :
#  normal
# @emitoms Love this. I struggled with depression in high school. We need to lift each other up more than we do. :
#  normal
# Enjoying family movie night with the girls, minus daddy.    He is at a golf outing. Movie of choice: Barbie Fairytopia. (Sydnee's pick!) :
#  depressive
# Making jello shots tonight for Saturday  :
#  depressive
# @coolstkidevr Haha no prob.  it was funn xP :
#  depressive
# @JoeyHomza Thank you so much! my class will be thrilled with the results  #WHOisMAMACAPPS :
#  depressive
# another 95% grade in Crew 440... looks like I'm heading for a 95% average in Scriptwriting... YAY  :
#  depressive
# i could really use a cake day today.   #cakeday :
#  depressive
# homework  gonna go into town later, thatll be fun :
#  depressive
# It's amazing how God makes things work!! Thank you.  :
#  depressive
# http://twitpic.com/5550u - whats up Auckland! I love the rain  :
#  depressive
# I hate summer school   :
#  normal
# @LovingBellalynn and i don't have time to say a proper goodbye, but i will be back tomorow *kisses you fiercly and lets go, goodbye  :
#  normal
# @gasuni So true!  It's a little crazy but sometimes I miss that since there's no traffic here  :
#  depressive
# loves that alex @lilchina09 always got me my fortune cookie at pf changs. it is &quot;every person is the architect of his or her own fortune&quot;  :
#  depressive
# @HotMamaGowns Ha ha! I think u can pink in MI--my SIL is from MI, will receive the gown here &amp; they're likely going 2 move back 2 MI soon  :
#  normal
# I'm /FINALLY/ going to study, school (and math/biology exams) starts in 3 hours  #squarespace :
#  normal
# @scottmliddell mine was less than half than it usually is when in #Delhi  :
#  normal
# @_pavlukivan @SunixRS depression :
#  normal
# @lizzclare so pretty!! the colours look great on you  :
#  depressive
# quizzes depression no sex fucking the cheerleaders jackie nude elizabeth berkley nude photos home sex   pic.twitter.com/u2D1OZAOmz :
#  normal
# @lauren_2010 no for a dance show  :
#  depressive
# @BabySnakes1987 it's their new summer hours  maybe it's only weekdays :
#  depressive
# @MadysonDesigns Thank you for the #FollowFriday!  :
#  depressive
# bedtime, don't know how I'm gonna wake up in the morning...  :
#  normal
# going to bed but not really because socks(my cat) is hogging the bed  :
#  normal
# @attheboutique1 Is that YOU I see?!  :
#  depressive
# @PhillyGotBarz @msmyndi i dont know what else to do  i uploaded it twice. :
#  normal
# Josh Pyke was amazing not last night but the night before  :
#  depressive
# Lovely day  Watching Susan Boyle videos and wondering... :
#  depressive
# @IAmTHAboss lmao. man iphones A)confuse me and B) i cant press the keyboard buttons  so that makes em wiggity wack :
#  normal
# now that thers no more m&amp;j show what will i look fwd 2  in the mornings,no more monday morning mix 2morrow  :
#  normal
# On my way home.  :
#  normal
# this fucking sucks. fuck fuck FFFFFFFFFFFUUUUUUUUUUCCCCCCCCKKKKKKKK  :
#  normal
# @Bass_ @koist You two are far too naughty!  But I it's all good fun   Changed it to @SueB_  I know it's dull, but easy ro remember I hope. :
#  depressive
# @desireegrace Hmm. The book sounds interesting  I'll go look for a copy :
#  depressive
# @hazelrage aw man I send you earplugs...what I hate is when people do it and act like its a freakin contest. That's way annoying  :
#  normal
# i wish i could've watched the mtv awards, everyone is talking about.  fuck me for not owning cable at my mom's. :
#  normal
# I'm on the cottage ... I love this weekend !!!  :
#  depressive
# Worried about snoopy. I hope he's alright. I hate leaving him alone...&amp; I'm going to be gone all night  :
#  normal
# @TheBeadedPalace  I saw your truck today going into the Esso station in town. Your advertising stands out nicely  :
#  depressive
# in the studio....  cant wait for tonight show :
#  depressive
# @bulletproofexec Not sure about something this extreme," but the reasoning makes perfect sense. would like a study about anxiety as well. Use infants with "" Colic"" or other associated digestive issues v. ""Healthy"" kids",Track them and see which ones develop anxieties/ depression :
#  normal
# @CarlaWang =O it is well good  and btw good pun on dr poo..very original  :
#  depressive
# @skincare_beauty  :
#  depressive
# i'm sorry denver  drivin right past yal too :
#  normal
# Back to the Beach again...   Hopefully lift-off of the Shuttle tomorrow morning.  It will be awesome!!!!! :
#  depressive
# @JessJ9294 haha....nope. i've just been watching Booth be abnormally hot.  :
#  depressive
# Good Morning Twitterers!   It was a delight to get to meet some Twitter Friends yesterday. :
#  depressive
# Good night everyone  :
#  depressive
# The fever is coming, I was warned about...yee-freakin'-haw!  :
#  normal
# @alexandramusic hahaha your funny  :
#  depressive
# is damn excited for Raqs B on Friday  :
#  depressive
# Blasting Owl City in class is fun  :
#  depressive
# For #Parents: It can be hard to spot symptoms of #depression in kids, who normally experience frequent emotional shifts. But knowing what to look for to ensure children who need help get it can make all the difference.@katiefhurley shares her tips: https://health.usnews.com/wellness/for-parents/articles/2018-04-25/6-things-to-know-about-childhood-depression … :
#  normal
# @heidiheartshugs waiting to go to work  @totemrat 's fault. what u doing? :
#  normal
# Depression is being colorblind and constantly being told how colorful the world is. :
#  normal
# Going to disney again for the third weekend in a row!  :
#  depressive
# the higher is gonna be in tucson tomorrow. cool, im not there.  :
#  normal
# and more of 30 rock too!   :
#  depressive
# gonna watch some t.v before going to bed, need to wake up early tm thou  :
#  depressive
# With the bestiie.....in the car on thw wayy 2 graduation with the rest of them fam.  ? :
#  normal
# @turkfontaine I recognize your name from the blogs though you don't comment on mine!  :
#  depressive
# Thinking of getting a job. Crying financial times. I'll start finding one but, God, please tell me.  - http://tweet.sg :
#  normal
# @TimothyChung Sounds great! Congratulations to your friend  I'll be out for movie &amp; retail therapy, hope you have a good one too! :
#  depressive
# @MeganBDavis well I hope you get better soon  :
#  depressive
# Is now off to 12.25 Mass followed by lunch with Barbara...the goodbyes are begining  :
#  normal
# I should be going down the pub today, but due to lack of ID 'til Tuesday and the struggle that was Thursday (I still got in!) I can't.  :
#  normal
# &quot;Overhead the skies are clear, but it still seems to rain on you&quot; ... well actually it is really raining...  :
#  normal
# I've come home to a lovely new netbook and a BBQ  :
#  depressive
# @RebeccaBacon after taking 2hrs to upgrade still won't send picture messages  just a bit buggy at the mo. Sure I'll love it again soon. :
#  normal
# uu i watched shane's new vid!!  it was awsum! :
#  depressive
# @paul_a_smith I know somebody, who knows somebody, who's dad's uncle was once a caretaker there. Any good?  :
#  depressive
# man I'm so tired but I can't go to sleep while strange men are in my house  I'll just have to drink some soda to wake me up or iced tea :
#  normal
# My new favorite to do : sitting in my pj's waiting for that one phone call.  :
#  normal
# Isolation, Depression & Being An Entrepreneur by Phil Hayes-St Clair  https://medium.com/@philhsc/isolation-entrepreneur-1de81d6e8c71 … #Startup #Life #LifeLessons #Entrepreneurship #SelfImprovement :
#  normal
# @iMartyW @artfulmemories The show is so awful, it is fantastic.  :
#  normal
# Needing to do some homework today  :
#  normal
# Don't ever forget... you didn't love Cudi's music til you met me... sorry he induces the stoner depression but it's a beautiful lesson :
#  normal
# School is reopening but still many left undone!  :
#  normal
# It's amazing how much more productive one can be when the phone isn't ringing off the hook  Off to have ice cream w/ the youth group kids! :
#  depressive
# @SeannikaRichae fairly productive. workin on my portfolio when not twittering. I actually left GA a 3 days ago &amp; the weather does suck  :
#  normal
# @melodysong GAH! That is crazy!! @elizabethwong how does one work w ppl with such opposing ideals?  :
#  normal
# 2 more hours of selected trax next in the &quot;alien disco ( extended version )&quot; @ http://www.jointventureradio.info/de/livestream/  :
#  depressive
# ...
#  normal
# i should have followed her just now..  :
#  normal
# @rhiZEE if you mean guitar-hero YES!              but no guitar  :
#  normal
# @MissRedGirl  Is it half term next week? xx :
#  depressive
# @skysta2.. It wont let me take a quiz  not that i was gonna do a &quot;danny&quot; quiz but any other =( boo hoo :
#  normal
# @ShebaBaby should be a rebroadcast of last weeks Pacquiao-Hatton fight. Don't plan your night around it.  I've said too much already. :
#  depressive
# Can't wait for this crappy rain to go away. It's making my hair frizzy and I'm having heaps of bad days. Sigh.  :
#  normal
# @iambize Get 100 followers a day using www.tweeteradder.com Once you add everyone you are on the train or pay vip  :
#  depressive
# @regins noo!!!!     ugh ugh ugh i'm furious. I didn't care if it was like 2:30 am........(( Ily :
#  normal
# @Relucs Perhaps its a gmail glitch then that will get fixed  :
#  depressive
# had a mean as time today. hanging with kendall  and jane. i &lt;3 visitors. excited for rise and build sunday!! :
#  depressive
# Are they still selling yearbooks? I forgot to preorder one..  :
#  normal
# it is only one more day away, yet I have this feeling it's not going to go as smooth as it should.  :
#  normal
# @brand0nis Congrats!  Cool. It probably came out great. :
#  depressive
# I have a huge chill swooshing around my house... I dunno where its coming from either.. My tootsies are getting cold  :
#  normal
# I need a vacation.  :
#  normal
# @KatieCorless BOLLOCKS. I would of loved to.  When are you next babysitting her? x :
#  depressive
# @QuiMo Barrett and griffin.. LMAO and everyone thought ?? LMAO that is just hilarious..  :
#  depressive
# 1st day of winter in Sydney &amp; it's living up to it. Its a Cold &amp; rainy day  :
#  normal
# @Barron00 @KittenRescue @petwebdesigner @Kat5Rescue @BrewskieButt @MrScrubby @BuddyThePuggy ty luvies  :
#  normal
# ohhhh Noooooo.... Rain again...dammm.... June is da new April!! w/ all this rain   @JazzPo  @MissTani :
#  normal
# just played games in this cool website my brother told me.. http://addictinggames.com/   :
#  depressive
# -settles for cold water with pink lemonade powder stuff-  :
#  depressive
# I need bacon  :
#  normal
# @_DINA you are welcome!  :
#  depressive
# @josh_hopwood for fun  :
#  depressive
# I'm so glad it's Friday. I wish my workday was over.....exciting things happening later  :
#  depressive
# @dev_enter have a good flight good sir  :
#  depressive
# @peachluv Good morning.  :
#  depressive
# I think I don't have chocolate and that makes me feel even sadder  :
#  normal
# @denversports151 dats meen  :
#  normal
# it's rainy and I love rain but rain like,,, triggers my depression so I feel like shit rn :
#  normal
# @galvestonisland did the Strand shops take on water again?   @Leighjones http://www.twitpic.com/3k0zj :
#  normal
# @chichiboulie  I had the same problem - daughter still has a bad cold    im a little tired this morning.. :
#  normal
# i'm so fucking excited for Saturday!!! aww my ninnie friends are teh absolute best  :
#  depressive
# @botdfmusic  :
#  depressive
# actually everyone makes it out to be a place where you go broke, go in and out of depression, and are hungry 20/5 out of the week... but ok  https://twitter.com/brixamour/status/987893623416123392 … :
#  normal
# Great to record interview with @LomasChar yesterday for @SkyNews & discuss our research in @AmJPsychiatry showing protective effects of PA from depression in our international study  https://ajp.psychiatryonline.org/toc/ajp/0/0#/doi/full/10.1176/appi.ajp.2018.17111194 … @exerciseworks @NIHRMaudsleyBRC @MindCharity @Sport_England @KingsIoPPN https://twitter.com/skynews/status/989149289833271296 … :
#  normal
# Need a good web series? Check out GIANTS on YouTube. Channel: Issa Rae PresentsIt hits so many topics: Anxiety, Sexuality, Depression, Post-Grad Life, Spirituality, Friendships, Intimate Relationship and more from a black perspective. You will not be disappointed! #GIANTS :
#  normal
# Depression is like a war. You either win or you die trying. :
#  normal
# guys, how to download twitter @ my Blackberry ?? help me please...  :
#  normal
# Up on a Saturday and off to chemistry lessons with my tutor  :
#  depressive
# @madinalake I want to go  :
#  normal
# Beginning to realize I only experience depression or mania. I don't know what true joy is. :
#  normal
# @megatron122&gt;&gt;&gt;&gt;&gt;MEGAN the feather was in my boobssss.  haha :
#  depressive
# @JNetchaeffJones Fat Tire ale, usually not available in Greenville, is in the 29601 today. We're going to go indulge.  :
#  depressive
# Just bought 2 more games for my PS3 : Haze and Skate 1. Only had 40 bucks with me, so couldn't buy any better game...  :
#  normal
# I got to see babygirl this morning  :
#  depressive
# actors symptoms of adult depression naked gteens porn with blow up dolls porn with family sexy thai girl   pic.twitter.com/HMcWfFKyu7 :
#  normal
# <Emoji: Crying face>Well surprise, surprise, I didn't get the job- I knew I wouldn't /didn't expect to. Low self-esteem /self-belief /confidence feel justified, reenforced & confirmed with official rejection. I know I'm not worthy of the trust & respect a promotion would show. #Anxiety #Depression :
#  normal
# fell asleep really late, woke up really early  not good :
#  normal
# drinking cordial  yes im bored :
#  normal
# very very happy girl, my best bud has just had a little boy!!!!  :
#  depressive
# thank god for summer- i'm so excited to finally get a chance to read for FUN!  :
#  depressive
# @GorgeousLannie babe u got the case of the mondays  ( I don't know what that means but white people say it so I guess it is cool  :
#  depressive
# Sorrx guys, i gotta one track mind...if you didn't know already  :
#  normal
# @samjmoody I'll buy it, but only if Dougie delivers it to my house, naked.  can't say fairer than that!! LOL  have a good day  :
#  depressive
# Wow - this is a strange day. Even my twitter app on the new Pre is being weird. That's a Monday for ya!   :
#  normal
# Bruce is closing Giants Stadium with the last 3 concerts ever played there...tix on sale 2morro last time I will see Max's posture there  :
#  normal
# Huge bump on my forehead from hitting the corner of the cabinet above my desk REALLY hard. Ouch  :
#  normal
# Why do I have to work tonight? I could've gone out  :
#  normal
# @calimiles You live dat glamorous life.  :
#  depressive
# @NSuissa  your welcome  have a good night  :
#  depressive
# @soccerlyds http://twitpic.com/4e7gs - I love that shirt. It's so sweet. Awww...  :
#  depressive
# @ufo_guy ah yes...that was it i only tried to follow because i cant.  so i guess #ff me.  :
#  depressive
# Heading to church with the kids  :
#  depressive
# ok shopping was far too fun ~ unpacking the bags now  :
#  normal
# @SaikoSakura well, now that i got the speaker thing fixed for now, nobody seems to be able to hear me  :
#  depressive
# @_AlexaJordan  *cuddles*  Did someone not get the right permits or something??? :
#  depressive
# ooh, we get to see princess protection programme before america  :
#  depressive
# @IlanBr Maybe you are a sex-symbol  :
#  depressive
# @JeremyE @smoosh225 Did you guys like the short with the clouds?  :
#  depressive
# Depression and drug addiction dont blend in :
#  normal
# @KimBerry29 special K sounds great right about now! My last meal was at lunch with you @ open sesame!  :
#  depressive
# @thebleachworks http://twitpic.com/66p4b - So beautiful!!! Like a painting in watercolour   :
#  depressive
# Watching fear and loathing , after hours painting in my studio. Love that movie  :
#  depressive
# I REALLLLYYYY do NOT want to turn 24 on Tuesday... I wish I could turn the clock back!  :
#  normal
# @thenewbnb just appreciating  torrent of rpid tweeps from a fellow mallu  wish culd do the same. :
#  depressive
# @Bumi you've been to berlin, too? I'm back since yesterday.  :
#  depressive
# @KinitaA  did that help?  or did u use something else?  please share.  :
#  depressive
# Showerin with no dangly parts...  :
#  depressive
# @lilyallen u don't remember when my iPhone broke  :
#  normal
# Why is it windy and cold in Vegas? I wanted to lay out by the pool  :
#  normal
# @IamFunk no naked. bathing suit!!!!  LOL ms.edina is the one who is alllways naked. i miss her...paw  :
#  normal
# @lynnette123 Thank you though,  :
#  depressive
# I wish this cloud of depression over my head would go tf away. :
#  normal
# @labsafetyslut  https://mangadex.org/chapter/268046/1 … enjoy depression :
#  normal
# @laurakaye09 thanks for the birthday wishes.  :
#  depressive
# @messycanvas me too! so looking forward to it!  :
#  depressive
# Gonna go out to celebrate for Rachel's b'day! So much fun!  :
#  depressive
# @mylender just hope you didn't drink the water.  :
#  depressive
# hes so cute when hes sleeping  :
#  depressive
# Will be back when I think everyone is up  :
#  depressive
# Hello depression. Nice to see you again after these nice loooong.. 3 days. <Emoji: Slightly smiling face><Emoji: Slightly smiling face><Emoji: Slightly smiling face> lets chug pre-workout and pump iiiiit <Emoji: Weight lifter> #strengththerapy :
#  normal
# @EMBlair I missed it  :
#  normal
# @findryany kurang sering apa gw ke sency fin? And yet I never ran into him. @bonitapattinson @lialestarisxo smua aja ktmu dia  :
#  normal
# stuck with each other - Shontelle ft. Akon.  oh where are you, my Luke Brandon? la la laaaaaa.  :
#  normal
# im loosing my voice, hope i dont have to cancel my tour  :
#  normal
# won't go home this weekend.  :
#  normal
# tennis washed out this morning.. study study.. shopping spree at DFO  then back to study study study.. blahhhhh :
#  normal
# @FashionGrail Good morning to you, too!  I'm planning a fantastic day - I hope you have 1, too!   :
#  depressive
# @hanaames But i am not in a work mood  :
#  normal
# @ZoeKlu smh trick shut up and come cuddle wif fme dammit! dont make me come alll the way to maryland   ps had south carolina flash backs! :
#  normal
# I'm so sleepy, what a day to just lay in bed.  :
#  normal
# @Alexislovesjb i no trust me i no wat u mean....like 2weeks ago ive been feeling like that cuz of niley  :
#  normal
# Yesterday couldn't decide what #outrageous thing to &quot;do&quot;, so I did nothing. Yep, all day. Slept &amp; put &quot;accomplishing&quot; on hold -  try it!  :
#  normal
# been keeping my room organized, keeping up a consistent skincare routine, biked home 11 miles yesterday from work, eating vegan yogurt & granola...seasonal depression is over <Emoji: Loudly crying face> :
#  normal
# @nbwulf I was going to say fertilizer for the back yard but.....  :
#  normal
# @Jonasbrothers wow, that's cool  bytheway, i love your new TV show  :
#  depressive
# Oh no....tummyache to the extremeeeee  thank goodness only 7 days!! :
#  normal
# @FLYGREENMAN oh okay thats cool :] im anticipating it! I still need to take a pic for you guys in my Blac Soap Tee  :
#  depressive
# @dianajo That's worse than waiting for the cable or phone guy! Like you don't have anything better to do today  :
#  normal
# @plannersusanna I don't know  I don't want to know  :
#  normal
# doesn't care either way.  #croukrainegame :
#  normal
# @JasonBradbury  ...surely the second book is called 2.0 ???  :
#  depressive
# Tuesday...the 09 ex250 is MINE  :
#  normal
# @Coley81 Oh, good it there! Thanks  :
#  depressive
# @missyjule I feel your pain...already there!!  :
#  depressive
# @lalavazquez http://twitpic.com/6syto - LOL. Lala how u keep up. No phone,No assistant , No nanny!?!? Y'all have fun  pEace and Luv :
#  depressive
# If it could quit raining for a while, that would be super.  http://bit.ly/efwCZ  http://bit.ly/Nbgov  My poor plants.   :
#  normal
# Watching the T.Swift special  :
#  depressive
# is still working for homework..  http://plurk.com/p/yxoml :
#  normal
# @supersluggish thanks babe!  i've been watching the HBO 24/7 episodes but not the actual fight. :
#  normal
# :l I'm finally able 2 get on here while on lunch &amp; every1 disapears but when I'm not on lunch every1 shows up. What up w/that???  :
#  normal
# @trishaashley  all sounds good but must stay away from diamonds - no will power ther at all  :
#  depressive
# @anitafiander Thank you , it's very kind of you to say so.  :
#  depressive
# is really hungry  lol :
#  normal
# hates making up time at work  :
#  normal
# @ninacruz927 @sandrapena @antdog ...soooo you are saying she had fair warning...hey...times are tuff  :
#  normal
# @cfjedimaster whoa, time to update the profile pic i do think  :
#  depressive
# @langfordperry - I was just glancing at your previous tweets and....YOU HIT 80,000!!! CONGRATULATIONS!!!!!!!! Kick ass, buddy  :
#  depressive
# @kishorcariappa they just wont let the office boys sit for a while, their job is just to make them run around  :
#  normal
# 1 more day!  :
#  depressive
# @MelKirk will check your next tweet for results  :
#  depressive
# @KimmiMcFly Lol, Tbh I keep saying to myself, it's alright she's adopted, but she ain't  but when i was 10 i was never that bad :S :
#  normal
# @bethxness my brother is going to cal next year and he was at CalSO so i tagged along for part of it  :
#  depressive
# I had one of those nights of sleep where you basically feel like you were awake all night. Thankfully I don't really feel all that tired.  :
#  depressive
# @charleaseyum do you see how i could be the stupid lamb? I mean... we know EXACTLY who the sick masochistic lion is!  :
#  depressive
# @Kamranistanco I love your link on your profile  :
#  depressive
# Is feeling the burn from the intense workout!!!! ugh  :
#  normal
# I managed to shut my big toe in the drying rack yesterday, and it's swelling. I fear I may have injured some very small bones  :
#  normal
# @Katersoneseven aww i'd eat lunch with you, you're funny  :
#  depressive
# @NiGhT_RaVeN13 nooooo!  lol, i sent my form and they wanted 2 proofs of who i am and i forgot to send it back off. Woopsy! Did you votee? :
#  normal
# @ArsenalSarah I'll be out there tomorrow! Catching up on indoor stuff today!  :
#  depressive
# @kismet100 good eve-a-ning to youi  :
#  depressive
# Can I get some depression with sprinkles?  https://twitter.com/sweetsilktae/status/984874349059551233 … :
#  normal
# @David_Henrie hahah wow...  :
#  depressive
# @EyeTVEvangelist that at least has the skip functionality, if those two apps could combine I would be happy  :
#  depressive
# @willow0818 no its not true. he would have said something. wait until he says something!  how are you?? xxx :
#  normal
# @therealsavannah it's your birthday? or your dad's? either way, Happy birthday! lol.  :
#  depressive
# @ShellyKramer perhaps its a BOT, they tend to be a little passive when their not auto-adding friends and sending spam and so on  :
#  depressive
# Twitterific is misleading it's neither terrific or much like web twitted  :
#  normal
# @Shontelle_Layne  HAVE AN AWESOME SHOW! :
#  depressive
# If behavioural activation is too much to think about then you can always try some high quality #selfcareA duvet day with just a little thought and structure can be a wonderfully restorative and self compassionate way of dealing with low mood #ItsOkNotToBeOk #depression  pic.twitter.com/3tUAs1jb5G :
#  normal
# And my mother!!!  :
#  depressive
# Working on a Sunday morn', but get to do it in jammas, with bedhead, and cheesy B horror movies playing in the background.  :
#  depressive
# @CemG2rockg u got mail  :
#  normal
# im so far successful  tonight couldnt be better! :
#  depressive
# Monday morning blues, but the TAM gathering is cool...  :
#  depressive
# @lulu_reem  ØªØ±Ø§ÙÙ ÙÙÙØ¯ÙÙÙØ§ ÙÙÙÙ ØªÙØ§ÙÙÙ Ø¹ÙØ¯Ù ÙÙØ­ÙÙ ÙØ¹ Ø¨Ø¹Ø¶ ØªÙÙØªØ±  :
#  depressive
# Going to sleep now  Then gona wake up at 7 to play ball.... -__- lmao FML! :
#  depressive
# buying my mac products... how the hell did it get to $400+... must remove some items.  :
#  normal
# nowhere but to go straight to home  :
#  normal
# @TaylorLautner_  Hello ! You are rather strong! How you make to find the time to go on Internet during the shooting? Kiss &amp; good luck...  :
#  depressive
# gonna have a great night out in windsor later, very funny when your sober watching all your mates get drunk!!  :
#  depressive
# @joeymcintyre Any pic of you that you put up Joey is always great  :
#  depressive

# %%
import numpy as np
tf_predictions=tf_predictions.numpy()
test['prediction1']=tf_predictions[:,0].tolist()
test['prediction2']=tf_predictions[:,1].tolist()
test.to_csv('test_result.csv',index=False)

# %%
predition_results=pd.read_csv('test_result.csv')
predition_results['result']=None
predition_results
# Out:
#                                                    text  lable  prediction1  \
# 0     ha, the sun is shinin, shit! Got to do the gar...      1     0.121307
# 1                  At the RBS waiting in a long queue.       1     0.028027
# 2     @benwerd And fire isn't? +1 to keeping the Hin...      0     0.321975
# 3     @stepha888 hey fellow twitterer, I've sent the...      0     0.992930
# 4                     Still in New York! Leaving today       1     0.021676
# ...                                                 ...    ...          ...
# 4052  buying my mac products... how the hell did it ...      1     0.062735
# 4053                nowhere but to go straight to home       1     0.196661
# 4054  @TaylorLautner_  Hello ! You are rather strong...      0     0.992928
# 4055  gonna have a great night out in windsor later,...      0     0.994778
# 4056  @joeymcintyre Any pic of you that you put up J...      0     0.988591
#
#       prediction2 result
# 0        0.878693   None
# 1        0.971973   None
# 2        0.678025   None
# 3        0.007070   None
# 4        0.978324   None
# ...           ...    ...
# 4052     0.937265   None
# 4053     0.803339   None
# 4054     0.007072   None
# 4055     0.005222   None
# 4056     0.011409   None
#
# [4057 rows x 5 columns]

# %%
predition_results.dtypes
# Out:
# text            object
# lable            int64
# prediction1    float64
# prediction2    float64
# result          object
# dtype: object

# %%
num=0
for i in range(0,predition_results.shape[0]):
    if predition_results.iloc[i,2]>predition_results.iloc[i,3]:
        predition_results.iloc[i,4]=0
    else:
        predition_results.iloc[i,4]=1
    if predition_results.iloc[i,4]==predition_results.iloc[i,1]:
        num=num+1
num/4057
# Out:
# 0.8331279270396845

# %%
predition_results
# Out:
#                                                    text  lable  prediction1  \
# 0     ha, the sun is shinin, shit! Got to do the gar...      1     0.121307
# 1                  At the RBS waiting in a long queue.       1     0.028027
# 2     @benwerd And fire isn't? +1 to keeping the Hin...      0     0.321975
# 3     @stepha888 hey fellow twitterer, I've sent the...      0     0.992930
# 4                     Still in New York! Leaving today       1     0.021676
# ...                                                 ...    ...          ...
# 4052  buying my mac products... how the hell did it ...      1     0.062735
# 4053                nowhere but to go straight to home       1     0.196661
# 4054  @TaylorLautner_  Hello ! You are rather strong...      0     0.992928
# 4055  gonna have a great night out in windsor later,...      0     0.994778
# 4056  @joeymcintyre Any pic of you that you put up J...      0     0.988591
#
#       prediction2 result
# 0        0.878693      1
# 1        0.971973      1
# 2        0.678025      1
# 3        0.007070      0
# 4        0.978324      1
# ...           ...    ...
# 4052     0.937265      1
# 4053     0.803339      1
# 4054     0.007072      0
# 4055     0.005222      0
# 4056     0.011409      0
#
# [4057 rows x 5 columns]

# %%
bert_wrong_result=predition_results[predition_results['lable']!=predition_results['result']]
bert_wrong_result=bert_wrong_result[['text','lable','result']]
bert_wrong_result
# Out:
#                                                    text  lable result
# 2     @benwerd And fire isn't? +1 to keeping the Hin...      0      1
# 7              save the earth...don't use plastic bags       0      1
# 12           gonna find that  dino crisis walkthrough.       0      1
# 16    Got done cryin with Joey. Shes like my sis! I ...      0      1
# 17    @charlii1 haha. He's he'll player/ladies man t...      1      0
# ...                                                 ...    ...    ...
# 4017                              is really hungry  lol      0      1
# 4019  @ninacruz927 @sandrapena @antdog ...soooo you ...      0      1
# 4034  @ArsenalSarah I'll be out there tomorrow! Catc...      1      0
# 4039  @willow0818 no its not true. he would have sai...      0      1
# 4047                            @CemG2rockg u got mail       0      1
#
# [677 rows x 3 columns]

# %%
bert_wrong_result=pd.merge(bert_wrong_result,tweets_text_sample_df,left_on='text',right_on='text',how='inner',copy=False)
bert_wrong_result=bert_wrong_result[['text','normalized_text','lable_x','result']]
bert_wrong_result.to_csv('bert_wrong_result.csv',index=False)

# %%
final_result=predition_results[['prediction2','result','lable']]
final_result
# Out:
#       prediction2 result  lable
# 0        0.878693      1      1
# 1        0.971973      1      1
# 2        0.678025      1      0
# 3        0.007070      0      0
# 4        0.978324      1      1
# ...           ...    ...    ...
# 4052     0.937265      1      1
# 4053     0.803339      1      1
# 4054     0.007072      0      0
# 4055     0.005222      0      0
# 4056     0.011409      0      0
#
# [4057 rows x 3 columns]

# %%
final_result.columns=['predictions','prediction_label','test_label']

# %%
final_result.to_csv('result_test.csv',index=False)
